# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[(data['Age'] > 22) & (data.Sex == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data = pd.read_csv('StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.groupby('lunch').aggregate({'math score': 'mean', 'reading score': 'mean', 'writing score': 'mean'})
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
data.groupby('lunch').aggregate({'math score': 'std', 'reading score': 'std', 'writing score': 'std'})
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   15.159956      14.895339      15.433823
# standard       13.653501      13.830602      14.339487

# %%
data = pd.read_csv('dota_hero_stats.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
data.groupby('legs').count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
data.groupby(['attack_type', 'primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
data.iloc[1]['roles']
# Out:
# "['Initiator', 'Durable', 'Disabler', 'Jungler']"

# %%
lenths = [len(r.split(',')) for r in data.roles]
data['lenths'] = lenths

# %%
data['lenths'].hist()
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv('accountancy.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
data.groupby(['Type', 'Executor']).mean()
# Out:
#                Unnamed: 0      Salary
# Type Executor
# A    Loopa      46.000000   58.000000
#      Pupa       16.000000  160.833333
# B    Loopa      24.000000  145.166667
#      Pupa       41.000000   77.000000
# C    Loopa      31.666667  154.333333
#      Pupa       23.000000   74.500000
# D    Loopa      31.857143  137.714286
#      Pupa       14.000000  146.500000
# E    Loopa      23.500000  164.000000
#      Pupa       19.800000  131.200000
# F    Loopa      20.000000  238.000000
#      Pupa       25.750000  136.250000

# %%
concentrations = pd.read_csv('algae.csv')

# %%
concentrations.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
mean_concentrations = concentrations.groupby('genus').mean()

# %%
concentrations.query("genus == 'Fucus'")['alanin'].describe()
# Out:
# count    3.000000
# mean     3.566411
# std      3.149943
# min      0.346431
# 25%      2.028965
# 50%      3.711498
# 75%      5.176401
# max      6.641303
# Name: alanin, dtype: float64

# %%
concentrations.groupby('group').aggregate({'citrate' : 'var'})
# Out:
#         citrate
# group
# brown  5.468942
# green  3.950113
# red         NaN

# %%
concentrations.groupby('group').aggregate({'sucrose' : 'max'}) - concentrations.groupby('group').aggregate({'sucrose' : 'min'})
# Out:
#         sucrose
# group
# brown  5.189345
# green  3.259662
# red    0.000000

# %%
df = pd.read_csv('income.csv')

# %%
import seaborn as sns

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv('dataset_209770_6.txt', sep=' ')

# %%
data.plot(kind='scatter', x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
data = pd.read_csv('genome_matrix.csv')

# %%
data.set_index('Unnamed: 0')
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data=data.set_index('Unnamed: 0'), cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
sns.heatmap(data=data.set_index('Unnamed: 0'), cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Unnamed: 0'>

# %%
data = pd.read_csv('iris.csv', index_col=0)

# %%
sns.displot(data, kind='kde')

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.violinplot(x=data['petal length'])
# Out:
# <AxesSubplot:xlabel='petal length'>

# %%
x = list(data.columns)
x.remove('species')
x
# Out:
# ['sepal length', 'sepal width', 'petal length', 'petal width']

# %%
sns.pairplot(data[x])

# %%
data = pd.read_csv('my_stat.csv')

# %%
data.iloc[:10,[0,2]]
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
pd.concat([data.iloc[0:1,[1,3]], data.iloc[2:5,[1,3]], data.iloc[6:,[1,3]]]).head(10)
# Out:
#       V2   V4
# 0   13.0  1.0
# 2   11.0  0.0
# 3   11.0  2.0
# 4   10.0 -1.0
# 6    9.0  2.0
# 7    9.0  1.0
# 8    9.0  2.0
# 9   10.0  0.0
# 10  10.0  1.0
# 11  10.0  1.0

# %%
data
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
data.groupby('V2', as_index=False, group_keys=False).agg({'V1': 'mean'})
# Out:
#      V2        V1
# 0   5.0  0.000000
# 1   7.0  0.333333
# 2   8.0  0.633333
# 3   9.0  0.238938
# 4  10.0  0.065990
# 5  11.0 -0.081081
# 6  12.0 -0.078947
# 7  13.0  0.000000
